# %% [markdown]
# Zjazd 5, część 1 — Ćwiczenia laboratoryjne
#
# Temat: Pandas — Series, DataFrame, eksploracja danych
# Programowanie w Pythonie II (studia niestacjonarne) | Zjazd 5, część 1 Czas: 90 min | Forma: ćwiczenia praktyczne

# %%
#Krok 1 — Series z listy i dict

import pandas as pd
import numpy as np

# Series z listy — domyślny indeks (0, 1, 2, ...)
oceny = pd.Series([4.5, 3.0, 5.0, 3.5, 4.0])
print(oceny)
# Out:
# 0    4.5
# 1    3.0
# 2    5.0
# 3    3.5
# 4    4.0
# dtype: float64

# %%
#Zadanie 1a: Utwórz Series pensje z dict:
# Klucze: 'Anna', 'Jan', 'Ewa', 'Marek', 'Kasia'
# Wartości: 5500, 7200, 4800, 9100, 6300

dane_zarobki = {
    'Anna': 5500,
    'Jan': 7200,
    'Ewa': 4800,
    'Marek': 9100,
    'Kasia': 6300
}

zarobki = pd.Series(dane_zarobki)

print(zarobki)
# Out:
# Anna     5500
# Jan      7200
# Ewa      4800
# Marek    9100
# Kasia    6300
# dtype: int64

# %%
#Zadanie 1b: Odpowiedz na pytania o pensje:
# 1. Wyświetl imię osoby zarabiającej najwięcej (użyj idxmax())
# 2. Oblicz średnią pensję
# 3. Wyświetl imiona osób zarabiających powyżej średniej (filtrowanie boolean)
# 4. Policz ile osób zarabia poniżej 6000 (użyj len() lub .sum())

imie_najwiekszyzarobek = zarobki.idxmax()
print(imie_najwiekszyzarobek)
srednia_pensja = zarobki.mean()
print(srednia_pensja)

above_average = dane_zarobki[(dane_zarobki > srednia_pensja)]

print(above_average)
# Out:
# Marek
# 6580.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 12
#       8 print(imie_najwiekszyzarobek)
#       9 srednia_pensja = zarobki.mean()
#      10 print(srednia_pensja)
#      11
# ---> 12 above_average = dane_zarobki > srednia_pensja
#      13
#      14 print(above_average)
#
# TypeError: '<' not supported between instances of 'float' and 'dict'

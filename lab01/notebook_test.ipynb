# %%
2+2

# %%
2+2
# Out:
# 4

# %%
import numpy as np

dane = np.array([10, 20, 30, 40, 50])
print(f"Średnia: {dane.mean()}")
print(f"Odchylenie standardowe: {dane.std():.2f}")
# Out:
# Średnia: 30.0
# Odchylenie standardowe: 14.14
